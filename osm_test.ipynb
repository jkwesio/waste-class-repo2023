# %%
import osmnx as ox
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %%
# read in US as graph
G = ox.graph_from_place('Massachusetts, USA', network_type='drive')

# %%
G = ox.io.load_graphml('data\MA_drive.osm')

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
ox.save_graphml(G,'data\MA_drive.osm')

# %%
G1 = ox.graph_from_place("Modena, Italy")

# %%
ox.plot_graph(G1)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
nx.draw(G1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 nx.draw(G1)
#
# File c:\Users\jacqu\anaconda3\envs\ox\Lib\site-packages\networkx\drawing\nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File c:\Users\jacqu\anaconda3\envs\ox\Lib\site-packages\networkx\drawing\nx_pylab.py:301, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     298 label_kwds = {k: v for k, v in kwds.items() if k in valid_label_kwds}
#     300 if pos is None:
# --> 301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
#     304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#
# File c:\Users\jacqu\anaconda3\envs\ox\Lib\site-packages\networkx\utils\decorators.py:766, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     765 def func(*args, __wrapper=None, **kwargs):
# --> 766     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 16:4, in argmap_spring_layout_13(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File c:\Users\jacqu\anaconda3\envs\ox\Lib\site-packages\networkx\drawing\layout.py:482, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     480         nnodes, _ = A.shape
#     481         k = dom_size / np.sqrt(nnodes)
# --> 482     pos = _sparse_fruchterman_reingold(
#     483         A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     484     )
#     485 except ValueError:
#     486     A = nx.to_numpy_array(G, weight=weight)
#
# File c:\Users\jacqu\anaconda3\envs\ox\Lib\site-packages\networkx\utils\decorators.py:766, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     765 def func(*args, __wrapper=None, **kwargs):
# --> 766     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 20:4, in argmap__sparse_fruchterman_reingold_17(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File c:\Users\jacqu\anaconda3\envs\ox\Lib\site-packages\networkx\drawing\layout.py:618, in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     616 delta = (pos[i] - pos).T
#     617 # distance between points
# --> 618 distance = np.sqrt((delta**2).sum(axis=0))
#     619 # enforce minimum distance of 0.01
#     620 distance = np.where(distance < 0.01, 0.01, distance)
#
# File c:\Users\jacqu\anaconda3\envs\ox\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
# use OSM tags to find landfills as points of interest, print number found
place_name = "Massachusetts, USA"
landfills_wNA = ox.geometries.geometries_from_place(place_name, tags={"landuse": "landfill"})
landfills = landfills_wNA.dropna(subset=['name']) # drop NA

print(f"Found {len(landfills)} landfills in {place_name}")

# print names of landfills found in place
for i,landfill in landfills.iterrows():
    print(f"{landfill['name']} \tat {landfill['addr:housenumber']} {landfill['addr:street']} \tin {landfill['addr:city']}, {landfill['addr:state']} {landfill['addr:postcode']}")
# Out:
# Found 32 landfills in Massachusetts, USA
# Nantucket Town Landfill 	at nan nan 	in nan, nan nan
# Orleans Transfer Station 	at nan nan 	in nan, nan nan
# Orleans Transfer Station 	at nan nan 	in nan, nan nan
# Town Landfill 	at nan nan 	in nan, nan nan
# Cohasset Heights Landfill 	at nan nan 	in nan, nan nan
# Norwell Town Dump 	at nan nan 	in nan, nan nan
# Crow Lane Landfill 	at nan nan 	in nan, nan nan
# Newbury Landfill 	at nan nan 	in nan, nan nan
# Shpack Landfill 	at nan nan 	in nan, nan nan
# Rumford Avenue Landfill and Composting Facility 	at nan nan 	in nan, nan nan
# Landfill Wheelabrator Saugus Inc. Ash Landfill 	at nan nan 	in nan, nan nan
# Waltham Street Landfill (capped) 	at nan nan 	in nan, nan nan
# Shaffer Landfill (closed) 	at nan nan 	in nan, nan nan
# Charles George Landfill Superfund Site 	at nan nan 	in nan, nan nan
# Titcomb Pit (Capped) 	at nan nan 	in nan, nan nan
# Waste Management (Capped) 	at nan nan 	in nan, nan nan
# old junkyard 	at nan nan 	in nan, nan nan
# Woburn Sanitary Landfill 	at nan nan 	in nan, nan nan
# Pan Am Railroad Landfill 	at nan nan 	in nan, nan nan
# asbestos lagoons landfill 	at nan nan 	in nan, nan nan
# Westford Street Landfill Solar Power Facility 	at 1028 Westford Street 	in Lowell, MA 01851
# Capped Landfill 	at nan nan 	in nan, nan nan
# Hudson 	at nan nan 	in nan, nan nan
# Nyanza Chemical Dump Site 	at nan nan 	in nan, nan nan
# Littleton Landfill Capped 	at nan nan 	in nan, nan nan
# Town of Groton Transfer Station 	at nan nan 	in nan, nan nan
# Amherst Transfer Station & Recycling Center 	at nan nan 	in nan, nan nan
# Southbridge Landfill 	at nan nan 	in nan, nan nan
# Sludge Landfill 	at nan nan 	in nan, nan nan
# Old Dump 	at nan nan 	in nan, nan nan
# Waste Management Connecticut Valley Landfill 	at nan nan 	in nan, nan nan
# South Hadley Landfill 	at nan nan 	in nan, nan nan

# %%
landfills.columns
# Out:
# Index(['nodes', 'landuse', 'massgis:ARTICLE97', 'massgis:ASSESS_ACR',
#        'massgis:ATT_DATE', 'massgis:DCAM_ID', 'massgis:DEED_ACRES',
#        'massgis:EOEAINVOLV', 'massgis:FEESYM', 'massgis:FEE_OWNER',
#        'massgis:FY_FUNDING', 'massgis:LEV_PROT', 'massgis:OS_DEED_BO',
#        'massgis:OS_DEED_PA', 'massgis:OS_ID', 'massgis:OWNER_ABRV',
#        'massgis:OWNER_TYPE', 'massgis:POLY_ID', 'massgis:PRIM_PURP',
#        'massgis:PUB_ACCESS', 'massgis:SITE_NAME', 'massgis:TOWN_ID', 'name',
#        'owner', 'ownership', 'protected', 'source', 'geometry', 'note',
#        'start_date', 'alt_name', 'official_name', 'source:alt_name',
#        'source:name', 'disused', 'ways', 'type', 'area', 'abandoned',
#        'addr:city', 'addr:housenumber', 'addr:postcode', 'addr:state',
#        'addr:street', 'operator', 'plant:method', 'plant:output:electricity',
#        'plant:source', 'power', 'ref:US:EIA', 'website', 'barrier', 'natural',
#        'created_by'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 [i['note'] for i in landfills]
#
# Cell In[40], line 1, in <listcomp>(.0)
# ----> 1 [i['note'] for i in landfills]
#
# TypeError: string indices must be integers, not 'str'
